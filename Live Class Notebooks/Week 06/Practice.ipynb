# %%
import pandas as pd 
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
def build_xor_model(hidden_layer_sizes = []): 
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)
    model = tf.keras.Sequential()
    for hidden_layer_size in hidden_layer_sizes: 
        model.add(tf.keras.layers.Dense(units = hidden_layer_size, activation = 'tanh'))
    model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))
    
    model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate = 1))
    return model

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

# %%
xor_model = build_xor_model(hidden_layer_sizes =[])
history = xor_model.fit(x =X, y = y, epochs =500)
losses=history.history['loss']
plt.plot(losses)
plt.show()
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 371ms/step - loss: 0.7139
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7074
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7042
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7024
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7011
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7001
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6993
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6986
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6979
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6974
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6969
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6965
# ...

# %%
xor_model=build_xor_model(hidden_layer_sizes = [2])
history = xor_model.fit(x = X, y = y, epochs =500)
losses =history.history['loss']
plt.plot(losses)
plt.show()
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 338ms/step - loss: 0.7033
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6992
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6971
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6957
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6944
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6932
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6921
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6910
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6898
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6887
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6874
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6861
# ...
